# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# load the data if you need to; if you have already loaded the data, you may comment this cell out
# -- DO NOT CHANGE THIS CELL -- #
# !mkdir /data
# !wget -P /data/ https://s3.amazonaws.com/video.udacity-data.com/topher/2018/May/5aea1b91_train-test-data/train-test-data.zip
# !unzip -n /data/train-test-data.zip -d /data

# %% [markdown]
# <div class="alert alert-info">**Note:** Workspaces automatically close connections after 30 minutes of inactivity (including inactivity while training!). Use the code snippet below to keep your workspace alive during training. (The active_session context manager is imported below.)
# </div>
# ```
# from workspace_utils import active_session
#
# with active_session():
#     train_model(num_epochs)
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np

# import utilities to keep workspaces alive during model training
# from workspace_utils import active_session

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

# %%
## DONE: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F

## DONE: Once you've define the network, you can instantiate it
# one example conv layer has been provided for you
from models import Net

use_cuda = torch.cuda.is_available()

net = Net()
if use_cuda:
    net = net.cuda()
print(net)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=43264, out_features=6362, bias=True)
#   (fc2): Linear(in_features=6362, out_features=935, bias=True)
#   (fc3): Linear(in_features=935, out_features=136, bias=True)
#   (dropout1): Dropout(p=0.1, inplace=False)
#   (dropout2): Dropout(p=0.1, inplace=False)
#   (dropout3): Dropout(p=0.2, inplace=False)
#   (dropout4): Dropout(p=0.2, inplace=False)
#   (dropout5): Dropout(p=0.4, inplace=False)
#   (dropout6): Dropout(p=0.4, inplace=False)
# )

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor


## DONE: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose([Rescale(250),
                                     RandomCrop(224),
                                     Normalize(),
                                     ToTensor()])

# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file='./data/training_frames_keypoints.csv',
                                             root_dir='./data/training/',
                                             transform=data_transform)


print('Number of images: ', len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains. Too large a batch size may cause your model to crash and/or run out of memory while training.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# load training/valid data in batches
num_workers = 0
batch_size = 10
valid_size = 0.1

num_train = len(transformed_dataset)
indices = list(range(num_train))
np.random.shuffle(indices)
split_idx = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split_idx:], indices[:split_idx]
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          sampler=train_sampler, 
                          num_workers=num_workers)

valid_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          sampler=valid_sampler, 
                          num_workers=num_workers)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file='./data/test_frames_keypoints.csv',
                                             root_dir='./data/test/',
                                             transform=data_transform)

# %%
# load test data in batches
test_loader = DataLoader(test_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Wrap the image in a Variable, so that the net can process it as input and track how it changes as the image moves through the network.
# 3. Make sure the image is a FloatTensor, which the model expects.
# 4. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        
        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints']

        # convert images to FloatTensors
        images = images.type(torch.FloatTensor)
        
        if use_cuda:
            images, key_pts = images.cuda(), key_pts.cuda()

        # forward pass to get net output
        output_pts = net(images)
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # break after first image is tested
        if i == 0:
            return images, output_pts, key_pts

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([10, 1, 224, 224])
# torch.Size([10, 68, 2])
# torch.Size([10, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='m')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):
    
    test_images, test_outputs = test_images.cpu(), test_outputs.cpu()

    for i in range(batch_size):
        plt.figure(figsize=(20,10))
        ax = plt.subplot(1, batch_size, i+1)

        # un-transform the image data
        image = test_images[i].data   # get the image from it's Variable wrapper
        image = image.cpu().numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        predicted_key_pts = predicted_key_pts.cpu().numpy()
        # undo normalization of keypoints  
        predicted_key_pts = predicted_key_pts*50.0+100
        
        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            gt_pts = gt_pts.cpu()
            ground_truth_pts = gt_pts[i]         
            ground_truth_pts = ground_truth_pts*50.0+100
        
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)
            
        plt.axis('off')

    plt.show()
    
# call it
visualize_output(test_images, test_outputs, gt_pts, batch_size)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## DONE: Define the loss and optimization
import torch.optim as optim

criterion = nn.MSELoss()

optimizer = optim.Adam(net.parameters(), lr = 0.001)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
def train_net(net, n_epochs):
    
    train_losses, valid_losses = [], []
    valid_loss_min = np.Inf

    # prepare the net for training
    net.train()

    for epoch in range(n_epochs):  # loop over the dataset multiple times
        
        running_loss = 0.0

        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            
            net.train()
            
            # zero the parameter (weight) gradients
            optimizer.zero_grad()
            
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor)
            images = images.type(torch.FloatTensor)
            
            if use_cuda:
                images, key_pts = images.cuda(), key_pts.cuda()

            output_pts = net(images)
            loss = criterion(output_pts, key_pts)
            loss.backward()
            optimizer.step()

            
            running_loss += loss.item()
            
            # print loss statistics
            with torch.no_grad():
                if batch_i % 10 == 9:    # print every 10 batches

                       
                    # validate the model 
                    net.eval()
                    valid_loss = 0.0
                    for data in valid_loader:
                        images = data['image']
                        key_pts = data['keypoints']
                        key_pts = key_pts.view(key_pts.size(0), -1)
                        key_pts = key_pts.type(torch.FloatTensor)
                        images = images.type(torch.FloatTensor)
                        if use_cuda:
                            images, key_pts = images.cuda(), key_pts.cuda()

                        output_pts = net(images)
                        loss = criterion(output_pts, key_pts)
                        valid_loss += loss.item()


                    valid_loss = valid_loss*1.0 / len(valid_loader.sampler) * batch_size
                    running_loss = running_loss/10

                    print('Epoch: {}, Batch: {}, Avg.TrainingLoss: {} \tAvg.validLoss: {}'.format(epoch + 1, batch_i+1, running_loss, valid_loss))
                    train_losses.append(running_loss)
                    valid_losses.append(valid_loss)

                    if valid_loss <= valid_loss_min:
                        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
                        valid_loss_min,
                        valid_loss))
                        torch.save(net.state_dict(), 'saved_models/keypoints_model_best_valid.pt')
                        valid_loss_min = valid_loss

                    running_loss = 0.0
                    valid_loss = 0.0
                    torch.cuda.empty_cache()

    print('Finished Training')
    return train_losses, valid_losses

# %%
# train your network
n_epochs = 35 # start small, and increase when you've decided on your model structure and hyperparams

# this is a Workspaces-specific context manager to keep the connection
# alive while training your model, not part of pytorch
# with active_session():

train_losses, valid_losses = train_net(net, n_epochs)
# Out:
# Epoch: 1, Batch: 10, Avg.TrainingLoss: 0.9130807608366013 	Avg.validLoss: 0.29869558666482826
# Validation loss decreased (inf --> 0.298696).  Saving model ...
# Epoch: 1, Batch: 20, Avg.TrainingLoss: 0.2370142877101898 	Avg.validLoss: 0.3088256789942008
# Epoch: 1, Batch: 30, Avg.TrainingLoss: 0.20528892278671265 	Avg.validLoss: 0.24433786856990328
# Validation loss decreased (0.298696 --> 0.244338).  Saving model ...
# Epoch: 1, Batch: 40, Avg.TrainingLoss: 0.1947588823735714 	Avg.validLoss: 0.19178821064661006
# Validation loss decreased (0.244338 --> 0.191788).  Saving model ...
# Epoch: 1, Batch: 50, Avg.TrainingLoss: 0.22089785933494568 	Avg.validLoss: 0.2657175619650438
# Epoch: 1, Batch: 60, Avg.TrainingLoss: 0.21532791405916213 	Avg.validLoss: 0.2257426765698918
# Epoch: 1, Batch: 70, Avg.TrainingLoss: 0.23484349250793457 	Avg.validLoss: 0.21785129723004526
# Epoch: 1, Batch: 80, Avg.TrainingLoss: 0.1964542403817177 	Avg.validLoss: 0.20152074214867777
# Epoch: 1, Batch: 90, Avg.TrainingLoss: 0.12539406269788742 	Avg.validLoss: 0.20200274346364028
# Epoch: 1, Batch: 100, Avg.TrainingLoss: 0.2303776316344738 	Avg.validLoss: 0.19148575260460032
# Validation loss decreased (0.191788 --> 0.191486).  Saving model ...
# Epoch: 1, Batch: 110, Avg.TrainingLoss: 0.20014252737164498 	Avg.validLoss: 0.20437276798348894
# Epoch: 1, Batch: 120, Avg.TrainingLoss: 0.19638031125068664 	Avg.validLoss: 0.20500588688374943
# Epoch: 1, Batch: 130, Avg.TrainingLoss: 0.19543063044548034 	Avg.validLoss: 0.25481924371567766
# Epoch: 1, Batch: 140, Avg.TrainingLoss: 0.21240674704313278 	Avg.validLoss: 0.19933733378531615
# Epoch: 1, Batch: 150, Avg.TrainingLoss: 0.24658868536353112 	Avg.validLoss: 0.2313259590654015
# Epoch: 1, Batch: 160, Avg.TrainingLoss: 0.18028385266661645 	Avg.validLoss: 0.21188015365876217
# Epoch: 1, Batch: 170, Avg.TrainingLoss: 0.16147537678480148 	Avg.validLoss: 0.17935988057210955
# Validation loss decreased (0.191486 --> 0.179360).  Saving model ...
# Epoch: 1, Batch: 180, Avg.TrainingLoss: 0.1884702131152153 	Avg.validLoss: 0.21576649794688804
# Epoch: 1, Batch: 190, Avg.TrainingLoss: 0.17294615954160691 	Avg.validLoss: 0.1818278696754075
# Epoch: 1, Batch: 200, Avg.TrainingLoss: 0.22142991423606873 	Avg.validLoss: 0.19540362167737388
# Epoch: 1, Batch: 210, Avg.TrainingLoss: 0.20534434020519257 	Avg.validLoss: 0.2452800664081739
# Epoch: 1, Batch: 220, Avg.TrainingLoss: 0.16518057882785797 	Avg.validLoss: 0.19786882930236058
# Epoch: 1, Batch: 230, Avg.TrainingLoss: 0.23852514401078223 	Avg.validLoss: 0.20341513710731715
# Epoch: 1, Batch: 240, Avg.TrainingLoss: 0.16736444532871247 	Avg.validLoss: 0.2071342218904137
# Epoch: 1, Batch: 250, Avg.TrainingLoss: 0.17735467851161957 	Avg.validLoss: 0.2031815282440599
# Epoch: 1, Batch: 260, Avg.TrainingLoss: 0.21150596141815187 	Avg.validLoss: 0.20265143816870762
# Epoch: 1, Batch: 270, Avg.TrainingLoss: 0.2347167983651161 	Avg.validLoss: 0.18574993325278938
# Epoch: 1, Batch: 280, Avg.TrainingLoss: 0.16901959776878356 	Avg.validLoss: 0.19256091186765992
# Epoch: 1, Batch: 290, Avg.TrainingLoss: 0.1975357249379158 	Avg.validLoss: 0.1877186847904514
# Epoch: 1, Batch: 300, Avg.TrainingLoss: 0.19095734059810637 	Avg.validLoss: 0.2411482776003766
# Epoch: 1, Batch: 310, Avg.TrainingLoss: 0.1831367328763008 	Avg.validLoss: 0.23002622143037058
# Epoch: 2, Batch: 10, Avg.TrainingLoss: 0.21821642220020293 	Avg.validLoss: 0.21907566750497487
# Epoch: 2, Batch: 20, Avg.TrainingLoss: 0.3469272553920746 	Avg.validLoss: 0.18176784189794792
# Epoch: 2, Batch: 30, Avg.TrainingLoss: 0.20849738121032715 	Avg.validLoss: 0.1750097869534713
# Validation loss decreased (0.179360 --> 0.175010).  Saving model ...
# Epoch: 2, Batch: 40, Avg.TrainingLoss: 0.16861296370625495 	Avg.validLoss: 0.21972590185314245
# Epoch: 2, Batch: 50, Avg.TrainingLoss: 0.18501626700162888 	Avg.validLoss: 0.2031032535425156
# Epoch: 2, Batch: 60, Avg.TrainingLoss: 0.1338726907968521 	Avg.validLoss: 0.20624020529878623
# Epoch: 2, Batch: 70, Avg.TrainingLoss: 0.1446924775838852 	Avg.validLoss: 0.1758850989271106
# Epoch: 2, Batch: 80, Avg.TrainingLoss: 0.15477948859333993 	Avg.validLoss: 0.19615307213426325
# Epoch: 2, Batch: 90, Avg.TrainingLoss: 0.1914146549999714 	Avg.validLoss: 0.16478302118750665
# Validation loss decreased (0.175010 --> 0.164783).  Saving model ...
# Epoch: 2, Batch: 100, Avg.TrainingLoss: 0.16543595641851425 	Avg.validLoss: 0.16777575985027876
# Epoch: 2, Batch: 110, Avg.TrainingLoss: 0.14308750480413437 	Avg.validLoss: 0.18822140733286136
# Epoch: 2, Batch: 120, Avg.TrainingLoss: 0.18206502348184586 	Avg.validLoss: 0.22303745990371426
# Epoch: 2, Batch: 130, Avg.TrainingLoss: 0.1884581372141838 	Avg.validLoss: 0.20688399371039662
# Epoch: 2, Batch: 140, Avg.TrainingLoss: 0.20841742753982545 	Avg.validLoss: 0.1877348898032497
# Epoch: 2, Batch: 150, Avg.TrainingLoss: 0.17257490903139114 	Avg.validLoss: 0.18080188575163053
# Epoch: 2, Batch: 160, Avg.TrainingLoss: 0.12446103468537331 	Avg.validLoss: 0.19431906822272116
# Epoch: 2, Batch: 170, Avg.TrainingLoss: 0.1732393704354763 	Avg.validLoss: 0.17960829649529705
# Epoch: 2, Batch: 180, Avg.TrainingLoss: 0.1724018543958664 	Avg.validLoss: 0.17618450621476753
# Epoch: 2, Batch: 190, Avg.TrainingLoss: 0.1638043701648712 	Avg.validLoss: 0.19994323890160964
# Epoch: 2, Batch: 200, Avg.TrainingLoss: 0.1298309288918972 	Avg.validLoss: 0.2074506049814252
# Epoch: 2, Batch: 210, Avg.TrainingLoss: 0.15075295493006707 	Avg.validLoss: 0.18550332614107629
# Epoch: 2, Batch: 220, Avg.TrainingLoss: 0.16080606058239938 	Avg.validLoss: 0.16991034882261574
# Epoch: 2, Batch: 230, Avg.TrainingLoss: 0.2021639347076416 	Avg.validLoss: 0.20691078834537135
# Epoch: 2, Batch: 240, Avg.TrainingLoss: 0.23213598877191544 	Avg.validLoss: 0.18229310869136986
# Epoch: 2, Batch: 250, Avg.TrainingLoss: 0.2063945099711418 	Avg.validLoss: 0.1974171574491297
# Epoch: 2, Batch: 260, Avg.TrainingLoss: 0.15318853929638862 	Avg.validLoss: 0.151962689581634
# Validation loss decreased (0.164783 --> 0.151963).  Saving model ...
# Epoch: 2, Batch: 270, Avg.TrainingLoss: 0.14826941192150117 	Avg.validLoss: 0.17561377785195506
# Epoch: 2, Batch: 280, Avg.TrainingLoss: 0.14458695650100709 	Avg.validLoss: 0.17179974780089594
# Epoch: 2, Batch: 290, Avg.TrainingLoss: 0.15618192106485368 	Avg.validLoss: 0.20226760191379944
# Epoch: 2, Batch: 300, Avg.TrainingLoss: 0.14456647336483003 	Avg.validLoss: 0.18287500452702446
# Epoch: 2, Batch: 310, Avg.TrainingLoss: 0.1975136898458004 	Avg.validLoss: 0.21452745325820294
# Epoch: 3, Batch: 10, Avg.TrainingLoss: 0.1635952465236187 	Avg.validLoss: 0.161316041872336
# Epoch: 3, Batch: 20, Avg.TrainingLoss: 0.14943054243922232 	Avg.validLoss: 0.21312552315823605
# Epoch: 3, Batch: 30, Avg.TrainingLoss: 0.24974944815039635 	Avg.validLoss: 0.15669008663107206
# Epoch: 3, Batch: 40, Avg.TrainingLoss: 0.1530226394534111 	Avg.validLoss: 0.16764500991285192
# Epoch: 3, Batch: 50, Avg.TrainingLoss: 0.1629343092441559 	Avg.validLoss: 0.17945915632854306
# Epoch: 3, Batch: 60, Avg.TrainingLoss: 0.12440956570208073 	Avg.validLoss: 0.1464450576832529
# Validation loss decreased (0.151963 --> 0.146445).  Saving model ...
# Epoch: 3, Batch: 70, Avg.TrainingLoss: 0.16029128208756446 	Avg.validLoss: 0.16354782560657213
# Epoch: 3, Batch: 80, Avg.TrainingLoss: 0.13241807669401168 	Avg.validLoss: 0.21193638433180104
# Epoch: 3, Batch: 90, Avg.TrainingLoss: 0.1155085165053606 	Avg.validLoss: 0.20302985854059286
# Epoch: 3, Batch: 100, Avg.TrainingLoss: 0.13778597488999367 	Avg.validLoss: 0.15964895723699835
# Epoch: 3, Batch: 110, Avg.TrainingLoss: 0.13747601583600044 	Avg.validLoss: 0.15371519157049285
# Epoch: 3, Batch: 120, Avg.TrainingLoss: 0.2185947686433792 	Avg.validLoss: 0.17057860765412364
# Epoch: 3, Batch: 130, Avg.TrainingLoss: 0.17925445064902307 	Avg.validLoss: 0.1654208031606812
# Epoch: 3, Batch: 140, Avg.TrainingLoss: 0.18705039098858833 	Avg.validLoss: 0.15171655189956545
# Epoch: 3, Batch: 150, Avg.TrainingLoss: 0.15457275062799453 	Avg.validLoss: 0.15472237149931792
# Epoch: 3, Batch: 160, Avg.TrainingLoss: 0.1506700709462166 	Avg.validLoss: 0.14747148573484722
# Epoch: 3, Batch: 170, Avg.TrainingLoss: 0.12191710844635964 	Avg.validLoss: 0.17489369700237506
# Epoch: 3, Batch: 180, Avg.TrainingLoss: 0.13313740044832229 	Avg.validLoss: 0.16760557782271004
# Epoch: 3, Batch: 190, Avg.TrainingLoss: 0.1641223795711994 	Avg.validLoss: 0.15644187323016925
# Epoch: 3, Batch: 200, Avg.TrainingLoss: 0.16581221893429757 	Avg.validLoss: 0.14471206071145962
# Validation loss decreased (0.146445 --> 0.144712).  Saving model ...
# Epoch: 3, Batch: 210, Avg.TrainingLoss: 0.16145649403333664 	Avg.validLoss: 0.1821188816014742
# Epoch: 3, Batch: 220, Avg.TrainingLoss: 0.1693828858435154 	Avg.validLoss: 0.20274903431448635
# Epoch: 3, Batch: 230, Avg.TrainingLoss: 0.17007457390427588 	Avg.validLoss: 0.1586812359921505
# Epoch: 3, Batch: 240, Avg.TrainingLoss: 0.16874695494771003 	Avg.validLoss: 0.20634439047102981
# Epoch: 3, Batch: 250, Avg.TrainingLoss: 0.16556432321667672 	Avg.validLoss: 0.17189482625337008
# Epoch: 3, Batch: 260, Avg.TrainingLoss: 0.1398274764418602 	Avg.validLoss: 0.17301559394408514
# Epoch: 3, Batch: 270, Avg.TrainingLoss: 0.10524955727159976 	Avg.validLoss: 0.1696691791273955
# Epoch: 3, Batch: 280, Avg.TrainingLoss: 0.28271346241235734 	Avg.validLoss: 0.14077232838366072
# Validation loss decreased (0.144712 --> 0.140772).  Saving model ...
# Epoch: 3, Batch: 290, Avg.TrainingLoss: 0.15217333547770978 	Avg.validLoss: 0.1648369646830366
# Epoch: 3, Batch: 300, Avg.TrainingLoss: 0.1310401052236557 	Avg.validLoss: 0.1881584742596384
# Epoch: 3, Batch: 310, Avg.TrainingLoss: 0.1687759727239609 	Avg.validLoss: 0.15932836499861902
# Epoch: 4, Batch: 10, Avg.TrainingLoss: 0.14777635931968688 	Avg.validLoss: 0.19076752223375903
# Epoch: 4, Batch: 20, Avg.TrainingLoss: 0.13122439458966256 	Avg.validLoss: 0.16719184191413008
# Epoch: 4, Batch: 30, Avg.TrainingLoss: 0.12962271198630332 	Avg.validLoss: 0.12612968155672785
# Validation loss decreased (0.140772 --> 0.126130).  Saving model ...
# Epoch: 4, Batch: 40, Avg.TrainingLoss: 0.14107760787010193 	Avg.validLoss: 0.1263071403897911
# Epoch: 4, Batch: 50, Avg.TrainingLoss: 0.11964292004704476 	Avg.validLoss: 0.12061474338776802
# Validation loss decreased (0.126130 --> 0.120615).  Saving model ...
# Epoch: 4, Batch: 60, Avg.TrainingLoss: 0.09812134988605976 	Avg.validLoss: 0.1579722341128512
# Epoch: 4, Batch: 70, Avg.TrainingLoss: 0.2792592402547598 	Avg.validLoss: 0.14750892501001414
# Epoch: 4, Batch: 80, Avg.TrainingLoss: 0.09513345323503017 	Avg.validLoss: 0.14018016011384182
# Epoch: 4, Batch: 90, Avg.TrainingLoss: 0.111101783066988 	Avg.validLoss: 0.12678953425991052
# Epoch: 4, Batch: 100, Avg.TrainingLoss: 0.2088049091398716 	Avg.validLoss: 0.16009689733988977
# Epoch: 4, Batch: 110, Avg.TrainingLoss: 0.14662253707647324 	Avg.validLoss: 0.1741865297208804
# Epoch: 4, Batch: 120, Avg.TrainingLoss: 0.12009577602148055 	Avg.validLoss: 0.14015366274841948
# Epoch: 4, Batch: 130, Avg.TrainingLoss: 0.1230908203870058 	Avg.validLoss: 0.12964073826984174
# Epoch: 4, Batch: 140, Avg.TrainingLoss: 0.3216173566877842 	Avg.validLoss: 0.19086774912355953
# Epoch: 4, Batch: 150, Avg.TrainingLoss: 0.14687154665589333 	Avg.validLoss: 0.12945298439247072
# Epoch: 4, Batch: 160, Avg.TrainingLoss: 0.11708004549145698 	Avg.validLoss: 0.14679777861244417
# Epoch: 4, Batch: 170, Avg.TrainingLoss: 0.11472466886043549 	Avg.validLoss: 0.12975200143981877
# Epoch: 4, Batch: 180, Avg.TrainingLoss: 0.10464483052492142 	Avg.validLoss: 0.1118164673727544
# Validation loss decreased (0.120615 --> 0.111816).  Saving model ...
# Epoch: 4, Batch: 190, Avg.TrainingLoss: 0.10645327158272266 	Avg.validLoss: 0.127655554971943
# Epoch: 4, Batch: 200, Avg.TrainingLoss: 0.0845616277307272 	Avg.validLoss: 0.13382705779089404
# Epoch: 4, Batch: 210, Avg.TrainingLoss: 0.09960779137909412 	Avg.validLoss: 0.12940443314698044
# Epoch: 4, Batch: 220, Avg.TrainingLoss: 0.0915654830634594 	Avg.validLoss: 0.09932191051930361
# Validation loss decreased (0.111816 --> 0.099322).  Saving model ...
# Epoch: 4, Batch: 230, Avg.TrainingLoss: 0.10663330741226673 	Avg.validLoss: 0.09177779671170809
# Validation loss decreased (0.099322 --> 0.091778).  Saving model ...
# Epoch: 4, Batch: 240, Avg.TrainingLoss: 0.10376079529523849 	Avg.validLoss: 0.09885635905269254
# Epoch: 4, Batch: 250, Avg.TrainingLoss: 0.09372909404337407 	Avg.validLoss: 0.12387163204953851
# Epoch: 4, Batch: 260, Avg.TrainingLoss: 0.08122786022722721 	Avg.validLoss: 0.07306198831755302
# Validation loss decreased (0.091778 --> 0.073062).  Saving model ...
# Epoch: 4, Batch: 270, Avg.TrainingLoss: 0.13330889753997327 	Avg.validLoss: 0.08645076692276607
# Epoch: 4, Batch: 280, Avg.TrainingLoss: 0.0979016300290823 	Avg.validLoss: 0.09820941620307161
# Epoch: 4, Batch: 290, Avg.TrainingLoss: 0.07946074157953262 	Avg.validLoss: 0.08191564066518593
# Epoch: 4, Batch: 300, Avg.TrainingLoss: 0.09567575752735138 	Avg.validLoss: 0.12278075206141939
# Epoch: 4, Batch: 310, Avg.TrainingLoss: 0.11760740056633949 	Avg.validLoss: 0.08215222184713177
# Epoch: 5, Batch: 10, Avg.TrainingLoss: 0.08889010027050973 	Avg.validLoss: 0.09695951132416036
# Epoch: 5, Batch: 20, Avg.TrainingLoss: 0.11012350097298622 	Avg.validLoss: 0.09972041090573534
# Epoch: 5, Batch: 30, Avg.TrainingLoss: 0.09798499308526516 	Avg.validLoss: 0.09620837996460799
# Epoch: 5, Batch: 40, Avg.TrainingLoss: 0.07579861395061016 	Avg.validLoss: 0.07988884323680333
# Epoch: 5, Batch: 50, Avg.TrainingLoss: 0.08636910282075405 	Avg.validLoss: 0.09862351360477808
# Epoch: 5, Batch: 60, Avg.TrainingLoss: 0.08551376461982726 	Avg.validLoss: 0.06275463709338552
# Validation loss decreased (0.073062 --> 0.062755).  Saving model ...
# Epoch: 5, Batch: 70, Avg.TrainingLoss: 0.12939639016985893 	Avg.validLoss: 0.12407597035944806
# Epoch: 5, Batch: 80, Avg.TrainingLoss: 0.08340780176222325 	Avg.validLoss: 0.08891031415217873
# Epoch: 5, Batch: 90, Avg.TrainingLoss: 0.1054640606045723 	Avg.validLoss: 0.12454078505838538
# Epoch: 5, Batch: 100, Avg.TrainingLoss: 0.12021565362811089 	Avg.validLoss: 0.0775439358946216
# Epoch: 5, Batch: 110, Avg.TrainingLoss: 0.0633187886327505 	Avg.validLoss: 0.1166151996938824
# Epoch: 5, Batch: 120, Avg.TrainingLoss: 0.10933470539748669 	Avg.validLoss: 0.07922190333032883
# Epoch: 5, Batch: 130, Avg.TrainingLoss: 0.09972813278436661 	Avg.validLoss: 0.13686927078517877
# Epoch: 5, Batch: 140, Avg.TrainingLoss: 0.0794762246310711 	Avg.validLoss: 0.11858890252995352
# Epoch: 5, Batch: 150, Avg.TrainingLoss: 0.07365142218768597 	Avg.validLoss: 0.13541446126609868
# Epoch: 5, Batch: 160, Avg.TrainingLoss: 0.07451519463211298 	Avg.validLoss: 0.10098825488777864
# Epoch: 5, Batch: 170, Avg.TrainingLoss: 0.0606817614287138 	Avg.validLoss: 0.07237273058450291
# Epoch: 5, Batch: 180, Avg.TrainingLoss: 0.08805167507380247 	Avg.validLoss: 0.07982039151207215
# Epoch: 5, Batch: 190, Avg.TrainingLoss: 0.06073819939047098 	Avg.validLoss: 0.0810288959801886
# Epoch: 5, Batch: 200, Avg.TrainingLoss: 0.10139664970338344 	Avg.validLoss: 0.0761347468081065
# Epoch: 5, Batch: 210, Avg.TrainingLoss: 0.0950734093785286 	Avg.validLoss: 0.10468673763118383
# Epoch: 5, Batch: 220, Avg.TrainingLoss: 0.09038650318980217 	Avg.validLoss: 0.08258560597035237
# Epoch: 5, Batch: 230, Avg.TrainingLoss: 0.06618662141263484 	Avg.validLoss: 0.11455283720972222
# Epoch: 5, Batch: 240, Avg.TrainingLoss: 0.08152021616697311 	Avg.validLoss: 0.09409961043022616
# Epoch: 5, Batch: 250, Avg.TrainingLoss: 0.09040614068508149 	Avg.validLoss: 0.08593769921689709
# Epoch: 5, Batch: 260, Avg.TrainingLoss: 0.05226652901619673 	Avg.validLoss: 0.11554947537450776
# Epoch: 5, Batch: 270, Avg.TrainingLoss: 0.0797982469201088 	Avg.validLoss: 0.09678469669353755
# Epoch: 5, Batch: 280, Avg.TrainingLoss: 0.06536970771849156 	Avg.validLoss: 0.07824881373759295
# Epoch: 5, Batch: 290, Avg.TrainingLoss: 0.061454618349671364 	Avg.validLoss: 0.10102909537452148
# Epoch: 5, Batch: 300, Avg.TrainingLoss: 0.06542105861008167 	Avg.validLoss: 0.07100248580120203
# Epoch: 5, Batch: 310, Avg.TrainingLoss: 0.0748437825590372 	Avg.validLoss: 0.13630141315691044
# Epoch: 6, Batch: 10, Avg.TrainingLoss: 0.06387598142027855 	Avg.validLoss: 0.10348794594234814
# Epoch: 6, Batch: 20, Avg.TrainingLoss: 0.08804520256817341 	Avg.validLoss: 0.07099199092629328
# Epoch: 6, Batch: 30, Avg.TrainingLoss: 0.07027213498950005 	Avg.validLoss: 0.10528290445103465
# Epoch: 6, Batch: 40, Avg.TrainingLoss: 0.07357356231659651 	Avg.validLoss: 0.04684095868485511
# Validation loss decreased (0.062755 --> 0.046841).  Saving model ...
# Epoch: 6, Batch: 50, Avg.TrainingLoss: 0.06548566725105047 	Avg.validLoss: 0.06633565718081989
# Epoch: 6, Batch: 60, Avg.TrainingLoss: 0.05969870276749134 	Avg.validLoss: 0.11957099978849722
# Epoch: 6, Batch: 70, Avg.TrainingLoss: 0.07363921441137791 	Avg.validLoss: 0.12443333368942228
# Epoch: 6, Batch: 80, Avg.TrainingLoss: 0.06440309882164001 	Avg.validLoss: 0.06756528975129816
# Epoch: 6, Batch: 90, Avg.TrainingLoss: 0.07005554512143135 	Avg.validLoss: 0.06604749935469187
# Epoch: 6, Batch: 100, Avg.TrainingLoss: 0.0823496326804161 	Avg.validLoss: 0.052483810725584196
# Epoch: 6, Batch: 110, Avg.TrainingLoss: 0.09561124220490455 	Avg.validLoss: 0.08841663103744474
# Epoch: 6, Batch: 120, Avg.TrainingLoss: 0.057089845463633535 	Avg.validLoss: 0.05773684327528311
# Epoch: 6, Batch: 130, Avg.TrainingLoss: 0.06571043394505978 	Avg.validLoss: 0.08388414262993144
# Epoch: 6, Batch: 140, Avg.TrainingLoss: 0.059490536153316495 	Avg.validLoss: 0.06896249917631893
# Epoch: 6, Batch: 150, Avg.TrainingLoss: 0.05711094886064529 	Avg.validLoss: 0.09328527602157152
# Epoch: 6, Batch: 160, Avg.TrainingLoss: 0.05215600561350584 	Avg.validLoss: 0.08089456104301992
# Epoch: 6, Batch: 170, Avg.TrainingLoss: 0.0530136289075017 	Avg.validLoss: 0.062073740699043166
# Epoch: 6, Batch: 180, Avg.TrainingLoss: 0.059438040107488634 	Avg.validLoss: 0.05087256991449808
# Epoch: 6, Batch: 190, Avg.TrainingLoss: 0.05993387065827847 	Avg.validLoss: 0.0627186344774989
# Epoch: 6, Batch: 200, Avg.TrainingLoss: 0.08772264011204242 	Avg.validLoss: 0.1372963253064135
# Epoch: 6, Batch: 210, Avg.TrainingLoss: 0.0673235459253192 	Avg.validLoss: 0.08804658573185434
# Epoch: 6, Batch: 220, Avg.TrainingLoss: 0.06698544323444366 	Avg.validLoss: 0.06981091320816148
# Epoch: 6, Batch: 230, Avg.TrainingLoss: 0.24093713089823723 	Avg.validLoss: 0.08400153610963008
# Epoch: 6, Batch: 240, Avg.TrainingLoss: 0.05988885089755058 	Avg.validLoss: 0.07283527549420823
# Epoch: 6, Batch: 250, Avg.TrainingLoss: 0.0526540070772171 	Avg.validLoss: 0.07803236279701223
# Epoch: 6, Batch: 260, Avg.TrainingLoss: 0.04637992661446333 	Avg.validLoss: 0.07655976216357223
# Epoch: 6, Batch: 270, Avg.TrainingLoss: 0.06544775981456041 	Avg.validLoss: 0.06715638606103859
# Epoch: 6, Batch: 280, Avg.TrainingLoss: 0.0748078390955925 	Avg.validLoss: 0.09991096273452216
# Epoch: 6, Batch: 290, Avg.TrainingLoss: 0.06773098781704903 	Avg.validLoss: 0.07523460943531783
# Epoch: 6, Batch: 300, Avg.TrainingLoss: 0.051232431456446646 	Avg.validLoss: 0.08013527781158858
# Epoch: 6, Batch: 310, Avg.TrainingLoss: 0.06442036069929599 	Avg.validLoss: 0.0846861421825052
# Epoch: 7, Batch: 10, Avg.TrainingLoss: 0.0532148502767086 	Avg.validLoss: 0.06634663349028268
# Epoch: 7, Batch: 20, Avg.TrainingLoss: 0.06443830113857985 	Avg.validLoss: 0.06284652746180233
# Epoch: 7, Batch: 30, Avg.TrainingLoss: 0.053989735804498194 	Avg.validLoss: 0.10125526114006264
# Epoch: 7, Batch: 40, Avg.TrainingLoss: 0.05984759069979191 	Avg.validLoss: 0.0440249250221976
# Validation loss decreased (0.046841 --> 0.044025).  Saving model ...
# Epoch: 7, Batch: 50, Avg.TrainingLoss: 0.05070605911314487 	Avg.validLoss: 0.04942284423233457
# Epoch: 7, Batch: 60, Avg.TrainingLoss: 0.0628335976973176 	Avg.validLoss: 0.06758384379649782
# Epoch: 7, Batch: 70, Avg.TrainingLoss: 0.048185141384601594 	Avg.validLoss: 0.07591962448262066
# Epoch: 7, Batch: 80, Avg.TrainingLoss: 0.09556035660207271 	Avg.validLoss: 0.10818357213341087
# Epoch: 7, Batch: 90, Avg.TrainingLoss: 0.06428031623363495 	Avg.validLoss: 0.11182922266983572
# Epoch: 7, Batch: 100, Avg.TrainingLoss: 0.07573227286338806 	Avg.validLoss: 0.08583832510633965
# Epoch: 7, Batch: 110, Avg.TrainingLoss: 0.07768302895128727 	Avg.validLoss: 0.09361200998241156
# Epoch: 7, Batch: 120, Avg.TrainingLoss: 0.07315113581717014 	Avg.validLoss: 0.05247628423950576
# Epoch: 7, Batch: 130, Avg.TrainingLoss: 0.06432571448385715 	Avg.validLoss: 0.05660264122951238
# Epoch: 7, Batch: 140, Avg.TrainingLoss: 0.05528232231736183 	Avg.validLoss: 0.08089468464513734
# Epoch: 7, Batch: 150, Avg.TrainingLoss: 0.04786160476505756 	Avg.validLoss: 0.07348102705843876
# Epoch: 7, Batch: 160, Avg.TrainingLoss: 0.05752879492938519 	Avg.validLoss: 0.05532761169005336
# Epoch: 7, Batch: 170, Avg.TrainingLoss: 0.048870745301246646 	Avg.validLoss: 0.07001673538948415
# Epoch: 7, Batch: 180, Avg.TrainingLoss: 0.053914470598101616 	Avg.validLoss: 0.04725270420097547
# Epoch: 7, Batch: 190, Avg.TrainingLoss: 0.08537810817360877 	Avg.validLoss: 0.058871429262822766
# Epoch: 7, Batch: 200, Avg.TrainingLoss: 0.14431922659277915 	Avg.validLoss: 0.061310038476579454
# Epoch: 7, Batch: 210, Avg.TrainingLoss: 0.058083095028996466 	Avg.validLoss: 0.05262541536220237
# Epoch: 7, Batch: 220, Avg.TrainingLoss: 0.07432715073227883 	Avg.validLoss: 0.0923605136724049
# Epoch: 7, Batch: 230, Avg.TrainingLoss: 0.0631882082670927 	Avg.validLoss: 0.0587248435577733
# Epoch: 7, Batch: 240, Avg.TrainingLoss: 0.04922652933746576 	Avg.validLoss: 0.07972376921747115
# Epoch: 7, Batch: 250, Avg.TrainingLoss: 0.05156538337469101 	Avg.validLoss: 0.11161193757646347
# Epoch: 7, Batch: 260, Avg.TrainingLoss: 0.04127057734876871 	Avg.validLoss: 0.06450176981918385
# Epoch: 7, Batch: 270, Avg.TrainingLoss: 0.06974622029811144 	Avg.validLoss: 0.05553611279653676
# Epoch: 7, Batch: 280, Avg.TrainingLoss: 0.046910631097853185 	Avg.validLoss: 0.049216157159192024
# Epoch: 7, Batch: 290, Avg.TrainingLoss: 0.05986155644059181 	Avg.validLoss: 0.06516149485580666
# Epoch: 7, Batch: 300, Avg.TrainingLoss: 0.07227162458002567 	Avg.validLoss: 0.04959743486103639
# Epoch: 7, Batch: 310, Avg.TrainingLoss: 0.049830883368849756 	Avg.validLoss: 0.06365854546126258
# Epoch: 8, Batch: 10, Avg.TrainingLoss: 0.14783939737826585 	Avg.validLoss: 0.07146723773007448
# Epoch: 8, Batch: 20, Avg.TrainingLoss: 0.05836351253092289 	Avg.validLoss: 0.06956241825713932
# Epoch: 8, Batch: 30, Avg.TrainingLoss: 0.06371725387871266 	Avg.validLoss: 0.11179478214569175
# Epoch: 8, Batch: 40, Avg.TrainingLoss: 0.0474907485768199 	Avg.validLoss: 0.055521699583771594
# Epoch: 8, Batch: 50, Avg.TrainingLoss: 0.06333930622786284 	Avg.validLoss: 0.08138008044246649
# Epoch: 8, Batch: 60, Avg.TrainingLoss: 0.054521146416664126 	Avg.validLoss: 0.047133129380772576
# Epoch: 8, Batch: 70, Avg.TrainingLoss: 0.06182608213275671 	Avg.validLoss: 0.09193316037427483
# Epoch: 8, Batch: 80, Avg.TrainingLoss: 0.05176484454423189 	Avg.validLoss: 0.06935826303555787
# Epoch: 8, Batch: 90, Avg.TrainingLoss: 0.042950876615941526 	Avg.validLoss: 0.045815209045231
# Epoch: 8, Batch: 100, Avg.TrainingLoss: 0.054303181171417234 	Avg.validLoss: 0.0657639574162619
# Epoch: 8, Batch: 110, Avg.TrainingLoss: 0.054151357337832454 	Avg.validLoss: 0.05879656831610065
# Epoch: 8, Batch: 120, Avg.TrainingLoss: 0.12508220002055168 	Avg.validLoss: 0.10883941562749402
# Epoch: 8, Batch: 130, Avg.TrainingLoss: 0.04816669952124357 	Avg.validLoss: 0.06392569937931665
# Epoch: 8, Batch: 140, Avg.TrainingLoss: 0.038168863765895365 	Avg.validLoss: 0.09833776494326618
# Epoch: 8, Batch: 150, Avg.TrainingLoss: 0.060882974229753015 	Avg.validLoss: 0.0925658232494758
# Epoch: 8, Batch: 160, Avg.TrainingLoss: 0.04226642176508903 	Avg.validLoss: 0.04281001230109634
# Validation loss decreased (0.044025 --> 0.042810).  Saving model ...
# Epoch: 8, Batch: 170, Avg.TrainingLoss: 0.06297620106488466 	Avg.validLoss: 0.04248125833927551
# Validation loss decreased (0.042810 --> 0.042481).  Saving model ...
# Epoch: 8, Batch: 180, Avg.TrainingLoss: 0.04863632805645466 	Avg.validLoss: 0.05080908041641202
# Epoch: 8, Batch: 190, Avg.TrainingLoss: 0.06656606048345566 	Avg.validLoss: 0.06282729449321252
# Epoch: 8, Batch: 200, Avg.TrainingLoss: 0.05236235912889242 	Avg.validLoss: 0.058844264359832504
# Epoch: 8, Batch: 210, Avg.TrainingLoss: 0.055771312303841115 	Avg.validLoss: 0.057601669286458476
# Epoch: 8, Batch: 220, Avg.TrainingLoss: 0.053190188482403755 	Avg.validLoss: 0.0710777046880281
# Epoch: 8, Batch: 230, Avg.TrainingLoss: 0.05389345809817314 	Avg.validLoss: 0.06627837201375837
# Epoch: 8, Batch: 240, Avg.TrainingLoss: 0.05025778468698263 	Avg.validLoss: 0.09048930143216097
# Epoch: 8, Batch: 250, Avg.TrainingLoss: 0.041378005780279635 	Avg.validLoss: 0.08195750033106074
# Epoch: 8, Batch: 260, Avg.TrainingLoss: 0.03964293394237757 	Avg.validLoss: 0.07074079707781704
# Epoch: 8, Batch: 270, Avg.TrainingLoss: 0.18522102385759354 	Avg.validLoss: 0.08871068095928328
# Epoch: 8, Batch: 280, Avg.TrainingLoss: 0.07572168260812759 	Avg.validLoss: 0.09983156500868715
# Epoch: 8, Batch: 290, Avg.TrainingLoss: 0.07673182785511017 	Avg.validLoss: 0.07895100474185338
# Epoch: 8, Batch: 300, Avg.TrainingLoss: 0.07978779468685389 	Avg.validLoss: 0.07086351562312918
# Epoch: 8, Batch: 310, Avg.TrainingLoss: 0.05519917495548725 	Avg.validLoss: 0.042962412204528816
# Epoch: 9, Batch: 10, Avg.TrainingLoss: 0.06021025627851486 	Avg.validLoss: 0.062169953050210294
# Epoch: 9, Batch: 20, Avg.TrainingLoss: 0.08645164929330348 	Avg.validLoss: 0.11193449673582019
# Epoch: 9, Batch: 30, Avg.TrainingLoss: 0.05797327272593975 	Avg.validLoss: 0.07736127581339695
# Epoch: 9, Batch: 40, Avg.TrainingLoss: 0.049758067913353445 	Avg.validLoss: 0.05582045682980491
# Epoch: 9, Batch: 50, Avg.TrainingLoss: 0.05568716898560524 	Avg.validLoss: 0.11940286828560291
# Epoch: 9, Batch: 60, Avg.TrainingLoss: 0.20477376375347375 	Avg.validLoss: 0.06712929474868182
# Epoch: 9, Batch: 70, Avg.TrainingLoss: 0.04974235985428095 	Avg.validLoss: 0.042598149927623695
# Epoch: 9, Batch: 80, Avg.TrainingLoss: 0.05968343541026115 	Avg.validLoss: 0.060561483812039296
# Epoch: 9, Batch: 90, Avg.TrainingLoss: 0.05634846612811088 	Avg.validLoss: 0.045014643783255814
# Epoch: 9, Batch: 100, Avg.TrainingLoss: 0.048462525755167005 	Avg.validLoss: 0.10059206929553105
# Epoch: 9, Batch: 110, Avg.TrainingLoss: 0.05036692731082439 	Avg.validLoss: 0.06370927433273352
# Epoch: 9, Batch: 120, Avg.TrainingLoss: 0.057554911077022555 	Avg.validLoss: 0.08818599788439756
# Epoch: 9, Batch: 130, Avg.TrainingLoss: 0.04249099511653185 	Avg.validLoss: 0.0806920348822726
# Epoch: 9, Batch: 140, Avg.TrainingLoss: 0.04917052779346705 	Avg.validLoss: 0.063174340922407
# Epoch: 9, Batch: 150, Avg.TrainingLoss: 0.06356588304042816 	Avg.validLoss: 0.056678635321256055
# Epoch: 9, Batch: 160, Avg.TrainingLoss: 0.038427889719605444 	Avg.validLoss: 0.0792460745964953
# Epoch: 9, Batch: 170, Avg.TrainingLoss: 0.04134488739073276 	Avg.validLoss: 0.05846240234728149
# Epoch: 9, Batch: 180, Avg.TrainingLoss: 0.0699708741158247 	Avg.validLoss: 0.057318501007565525
# Epoch: 9, Batch: 190, Avg.TrainingLoss: 0.052570479921996593 	Avg.validLoss: 0.06886909075210548
# Epoch: 9, Batch: 200, Avg.TrainingLoss: 0.04428442325443029 	Avg.validLoss: 0.08492986184431811
# Epoch: 9, Batch: 210, Avg.TrainingLoss: 0.045885895006358625 	Avg.validLoss: 0.042639783007561126
# Epoch: 9, Batch: 220, Avg.TrainingLoss: 0.03982646875083447 	Avg.validLoss: 0.058033648135431236
# Epoch: 9, Batch: 230, Avg.TrainingLoss: 0.07539041843265296 	Avg.validLoss: 0.055194309632686865
# Epoch: 9, Batch: 240, Avg.TrainingLoss: 0.04752811454236507 	Avg.validLoss: 0.08418156560833398
# Epoch: 9, Batch: 250, Avg.TrainingLoss: 0.0421834584325552 	Avg.validLoss: 0.08149514335471426
# Epoch: 9, Batch: 260, Avg.TrainingLoss: 0.04512710440903902 	Avg.validLoss: 0.04181452547711444
# Validation loss decreased (0.042481 --> 0.041815).  Saving model ...
# Epoch: 9, Batch: 270, Avg.TrainingLoss: 0.04868129715323448 	Avg.validLoss: 0.05693965613023739
# Epoch: 9, Batch: 280, Avg.TrainingLoss: 0.04897772558033466 	Avg.validLoss: 0.06914893961969139
# Epoch: 9, Batch: 290, Avg.TrainingLoss: 0.05165819674730301 	Avg.validLoss: 0.04258374705092411
# Epoch: 9, Batch: 300, Avg.TrainingLoss: 0.035541385784745215 	Avg.validLoss: 0.07314588562343162
# Epoch: 9, Batch: 310, Avg.TrainingLoss: 0.04556269031018019 	Avg.validLoss: 0.06099067154647298
# Epoch: 10, Batch: 10, Avg.TrainingLoss: 0.0578427866101265 	Avg.validLoss: 0.04012869175717321
# Validation loss decreased (0.041815 --> 0.040129).  Saving model ...
# Epoch: 10, Batch: 20, Avg.TrainingLoss: 0.03627617117017508 	Avg.validLoss: 0.12701803807578335
# Epoch: 10, Batch: 30, Avg.TrainingLoss: 0.036744257993996145 	Avg.validLoss: 0.056376142072022996
# Epoch: 10, Batch: 40, Avg.TrainingLoss: 0.04906403440982103 	Avg.validLoss: 0.07165684316285773
# Epoch: 10, Batch: 50, Avg.TrainingLoss: 0.051296027936041357 	Avg.validLoss: 0.08709170925565538
# Epoch: 10, Batch: 60, Avg.TrainingLoss: 0.07825313936918973 	Avg.validLoss: 0.07278509545705222
# Epoch: 10, Batch: 70, Avg.TrainingLoss: 0.04699857141822576 	Avg.validLoss: 0.036425037212626785
# Validation loss decreased (0.040129 --> 0.036425).  Saving model ...
# Epoch: 10, Batch: 80, Avg.TrainingLoss: 0.06722629740834236 	Avg.validLoss: 0.07210546350806435
# Epoch: 10, Batch: 90, Avg.TrainingLoss: 0.06775132287293673 	Avg.validLoss: 0.043717204792306605
# Epoch: 10, Batch: 100, Avg.TrainingLoss: 0.0831277135759592 	Avg.validLoss: 0.03520798637946217
# Validation loss decreased (0.036425 --> 0.035208).  Saving model ...
# Epoch: 10, Batch: 110, Avg.TrainingLoss: 0.05074170380830765 	Avg.validLoss: 0.0831593389520583
# Epoch: 10, Batch: 120, Avg.TrainingLoss: 0.050092180445790294 	Avg.validLoss: 0.05653621144377428
# Epoch: 10, Batch: 130, Avg.TrainingLoss: 0.04842459186911583 	Avg.validLoss: 0.07531705683883215
# Epoch: 10, Batch: 140, Avg.TrainingLoss: 0.05749512016773224 	Avg.validLoss: 0.05604973660426677
# Epoch: 10, Batch: 150, Avg.TrainingLoss: 0.15575364641845227 	Avg.validLoss: 0.08438589320534226
# Epoch: 10, Batch: 160, Avg.TrainingLoss: 0.043100671283900736 	Avg.validLoss: 0.08755004345681626
# Epoch: 10, Batch: 170, Avg.TrainingLoss: 0.04509484115988016 	Avg.validLoss: 0.0633897091870363
# Epoch: 10, Batch: 180, Avg.TrainingLoss: 0.04348922874778509 	Avg.validLoss: 0.07977478243841256
# Epoch: 10, Batch: 190, Avg.TrainingLoss: 0.05977934636175632 	Avg.validLoss: 0.048080514685783775
# Epoch: 10, Batch: 200, Avg.TrainingLoss: 0.05263005085289478 	Avg.validLoss: 0.051988281869474864
# Epoch: 10, Batch: 210, Avg.TrainingLoss: 0.06489109713584185 	Avg.validLoss: 0.07997322439975132
# Epoch: 10, Batch: 220, Avg.TrainingLoss: 0.06171302534639835 	Avg.validLoss: 0.043115696649072485
# Epoch: 10, Batch: 230, Avg.TrainingLoss: 0.0936502456665039 	Avg.validLoss: 0.07426875438864176
# Epoch: 10, Batch: 240, Avg.TrainingLoss: 0.055553579889237883 	Avg.validLoss: 0.04128237782487636
# Epoch: 10, Batch: 250, Avg.TrainingLoss: 0.040088916383683684 	Avg.validLoss: 0.038398712270521704
# Epoch: 10, Batch: 260, Avg.TrainingLoss: 0.04810644555836916 	Avg.validLoss: 0.053257814263978784
# Epoch: 10, Batch: 270, Avg.TrainingLoss: 0.04001755639910698 	Avg.validLoss: 0.07043059516934991
# Epoch: 10, Batch: 280, Avg.TrainingLoss: 0.03461078628897667 	Avg.validLoss: 0.042162915729416925
# Epoch: 10, Batch: 290, Avg.TrainingLoss: 0.042769262567162514 	Avg.validLoss: 0.06024324133281591
# Epoch: 10, Batch: 300, Avg.TrainingLoss: 0.03860130198299885 	Avg.validLoss: 0.05083989664223153
# Epoch: 10, Batch: 310, Avg.TrainingLoss: 0.036758619360625744 	Avg.validLoss: 0.03782831299296349
# Epoch: 11, Batch: 10, Avg.TrainingLoss: 0.10210330840200185 	Avg.validLoss: 0.08979961814391131
# Epoch: 11, Batch: 20, Avg.TrainingLoss: 0.048081588186323646 	Avg.validLoss: 0.05724986670592617
# Epoch: 11, Batch: 30, Avg.TrainingLoss: 0.06319494098424912 	Avg.validLoss: 0.09557154503344112
# Epoch: 11, Batch: 40, Avg.TrainingLoss: 0.0469201922416687 	Avg.validLoss: 0.038636959873871994
# Epoch: 11, Batch: 50, Avg.TrainingLoss: 0.06190018430352211 	Avg.validLoss: 0.09349129738749107
# Epoch: 11, Batch: 60, Avg.TrainingLoss: 0.05581912323832512 	Avg.validLoss: 0.11054426087120366
# Epoch: 11, Batch: 70, Avg.TrainingLoss: 0.0605823066085577 	Avg.validLoss: 0.0784810510264828
# Epoch: 11, Batch: 80, Avg.TrainingLoss: 0.04568850379437208 	Avg.validLoss: 0.06533174447155413
# Epoch: 11, Batch: 90, Avg.TrainingLoss: 0.043641284480690955 	Avg.validLoss: 0.08157748395221771
# Epoch: 11, Batch: 100, Avg.TrainingLoss: 0.03692225310951471 	Avg.validLoss: 0.09793940215570734
# Epoch: 11, Batch: 110, Avg.TrainingLoss: 0.04242374375462532 	Avg.validLoss: 0.07191820457749973
# Epoch: 11, Batch: 120, Avg.TrainingLoss: 0.042036693543195724 	Avg.validLoss: 0.058505878423076835
# Epoch: 11, Batch: 130, Avg.TrainingLoss: 0.045934310927987096 	Avg.validLoss: 0.06433320815831078
# Epoch: 11, Batch: 140, Avg.TrainingLoss: 0.046162312477827074 	Avg.validLoss: 0.06078838074655202
# Epoch: 11, Batch: 150, Avg.TrainingLoss: 0.053386722691357136 	Avg.validLoss: 0.03769679996319589
# Epoch: 11, Batch: 160, Avg.TrainingLoss: 0.06239939406514168 	Avg.validLoss: 0.03907011654981644
# Epoch: 11, Batch: 170, Avg.TrainingLoss: 0.05922574792057276 	Avg.validLoss: 0.08072195709225416
# Epoch: 11, Batch: 180, Avg.TrainingLoss: 0.04083023443818092 	Avg.validLoss: 0.0533360450103276
# Epoch: 11, Batch: 190, Avg.TrainingLoss: 0.04587132055312395 	Avg.validLoss: 0.1071611283659246
# Epoch: 11, Batch: 200, Avg.TrainingLoss: 0.04755741320550442 	Avg.validLoss: 0.052381881345817116
# Epoch: 11, Batch: 210, Avg.TrainingLoss: 0.0336758978664875 	Avg.validLoss: 0.08757980669595603
# Epoch: 11, Batch: 220, Avg.TrainingLoss: 0.08536158744245767 	Avg.validLoss: 0.07154077377622527
# Epoch: 11, Batch: 230, Avg.TrainingLoss: 0.05912269987165928 	Avg.validLoss: 0.08254807657761382
# Epoch: 11, Batch: 240, Avg.TrainingLoss: 0.04508677292615175 	Avg.validLoss: 0.09951158900438362
# Epoch: 11, Batch: 250, Avg.TrainingLoss: 0.057229868695139886 	Avg.validLoss: 0.05988278442380056
# Epoch: 11, Batch: 260, Avg.TrainingLoss: 0.050119456648826596 	Avg.validLoss: 0.09567763064207369
# Epoch: 11, Batch: 270, Avg.TrainingLoss: 0.04049323219805956 	Avg.validLoss: 0.05460554147085358
# Epoch: 11, Batch: 280, Avg.TrainingLoss: 0.07020433936268092 	Avg.validLoss: 0.10873660784365469
# Epoch: 11, Batch: 290, Avg.TrainingLoss: 0.054638857021927834 	Avg.validLoss: 0.0589365718853956
# Epoch: 11, Batch: 300, Avg.TrainingLoss: 0.06173679009079933 	Avg.validLoss: 0.08346266086304809
# Epoch: 11, Batch: 310, Avg.TrainingLoss: 0.04889723751693964 	Avg.validLoss: 0.0785163776259977
# Epoch: 12, Batch: 10, Avg.TrainingLoss: 0.04404619988054037 	Avg.validLoss: 0.12465612884783159
# Epoch: 12, Batch: 20, Avg.TrainingLoss: 0.04123788736760616 	Avg.validLoss: 0.05068363847932375
# Epoch: 12, Batch: 30, Avg.TrainingLoss: 0.04620437398552894 	Avg.validLoss: 0.06577203464775072
# Epoch: 12, Batch: 40, Avg.TrainingLoss: 0.056258860789239404 	Avg.validLoss: 0.08247322876630836
# Epoch: 12, Batch: 50, Avg.TrainingLoss: 0.04026123210787773 	Avg.validLoss: 0.06878230381606286
# Epoch: 12, Batch: 60, Avg.TrainingLoss: 0.040744961239397526 	Avg.validLoss: 0.043634773700395764
# Epoch: 12, Batch: 70, Avg.TrainingLoss: 0.04410523883998394 	Avg.validLoss: 0.04773039346550069
# Epoch: 12, Batch: 80, Avg.TrainingLoss: 0.033311588875949386 	Avg.validLoss: 0.06343422191099107
# Epoch: 12, Batch: 90, Avg.TrainingLoss: 0.054327227361500266 	Avg.validLoss: 0.03299763450409808
# Validation loss decreased (0.035208 --> 0.032998).  Saving model ...
# Epoch: 12, Batch: 100, Avg.TrainingLoss: 0.041902738809585574 	Avg.validLoss: 0.05016699384876414
# Epoch: 12, Batch: 110, Avg.TrainingLoss: 0.09392455406486988 	Avg.validLoss: 0.10244953376106444
# Epoch: 12, Batch: 120, Avg.TrainingLoss: 0.09471336640417576 	Avg.validLoss: 0.06614756921166284
# Epoch: 12, Batch: 130, Avg.TrainingLoss: 0.05049329549074173 	Avg.validLoss: 0.044208441597188834
# Epoch: 12, Batch: 140, Avg.TrainingLoss: 0.09662902876734733 	Avg.validLoss: 0.09575829082141721
# Epoch: 12, Batch: 150, Avg.TrainingLoss: 0.11719946432858705 	Avg.validLoss: 0.0560601085230622
# Epoch: 12, Batch: 160, Avg.TrainingLoss: 0.0375059150159359 	Avg.validLoss: 0.03700987958063969
# Epoch: 12, Batch: 170, Avg.TrainingLoss: 0.07200814485549926 	Avg.validLoss: 0.05578483632534226
# Epoch: 12, Batch: 180, Avg.TrainingLoss: 0.05357454195618629 	Avg.validLoss: 0.04152093397593395
# Epoch: 12, Batch: 190, Avg.TrainingLoss: 0.04959960523992777 	Avg.validLoss: 0.061384073237893896
# Epoch: 12, Batch: 200, Avg.TrainingLoss: 0.05027060806751251 	Avg.validLoss: 0.06191505377606161
# Epoch: 12, Batch: 210, Avg.TrainingLoss: 0.05687428265810013 	Avg.validLoss: 0.033798203776682044
# Epoch: 12, Batch: 220, Avg.TrainingLoss: 0.06581256985664367 	Avg.validLoss: 0.05207287077657405
# Epoch: 12, Batch: 230, Avg.TrainingLoss: 0.04062195923179388 	Avg.validLoss: 0.060351926758024046
# Epoch: 12, Batch: 240, Avg.TrainingLoss: 0.07225752230733633 	Avg.validLoss: 0.04221150172454429
# Epoch: 12, Batch: 250, Avg.TrainingLoss: 0.04561182241886854 	Avg.validLoss: 0.03407445391693901
# Epoch: 12, Batch: 260, Avg.TrainingLoss: 0.06184856779873371 	Avg.validLoss: 0.04414254573383772
# Epoch: 12, Batch: 270, Avg.TrainingLoss: 0.04946419671177864 	Avg.validLoss: 0.042058552879129525
# Epoch: 12, Batch: 280, Avg.TrainingLoss: 0.05966055579483509 	Avg.validLoss: 0.0743534240462532
# Epoch: 12, Batch: 290, Avg.TrainingLoss: 0.04740617815405131 	Avg.validLoss: 0.03530151528343989
# Epoch: 12, Batch: 300, Avg.TrainingLoss: 0.0547138599678874 	Avg.validLoss: 0.0580269370680255
# Epoch: 12, Batch: 310, Avg.TrainingLoss: 0.038428809866309165 	Avg.validLoss: 0.039495109645057626
# Epoch: 13, Batch: 10, Avg.TrainingLoss: 0.052246521972119805 	Avg.validLoss: 0.0645769245901032
# Epoch: 13, Batch: 20, Avg.TrainingLoss: 0.043690523505210875 	Avg.validLoss: 0.05516121153197537
# Epoch: 13, Batch: 30, Avg.TrainingLoss: 0.0398963987827301 	Avg.validLoss: 0.05162537482841684
# Epoch: 13, Batch: 40, Avg.TrainingLoss: 0.046568420715630054 	Avg.validLoss: 0.042254616845549875
# Epoch: 13, Batch: 50, Avg.TrainingLoss: 0.048761851526796816 	Avg.validLoss: 0.06633752305598961
# Epoch: 13, Batch: 60, Avg.TrainingLoss: 0.04019948244094849 	Avg.validLoss: 0.05363550187879904
# Epoch: 13, Batch: 70, Avg.TrainingLoss: 0.04922053944319486 	Avg.validLoss: 0.05557885016664604
# Epoch: 13, Batch: 80, Avg.TrainingLoss: 0.041555667854845525 	Avg.validLoss: 0.04985950367708255
# Epoch: 13, Batch: 90, Avg.TrainingLoss: 0.050356628745794295 	Avg.validLoss: 0.07457683966468179
# Epoch: 13, Batch: 100, Avg.TrainingLoss: 0.03394030164927244 	Avg.validLoss: 0.037790886745545905
# Epoch: 13, Batch: 110, Avg.TrainingLoss: 0.04011591374874115 	Avg.validLoss: 0.045005222190322214
# Epoch: 13, Batch: 120, Avg.TrainingLoss: 0.05426265597343445 	Avg.validLoss: 0.05106887971239455
# Epoch: 13, Batch: 130, Avg.TrainingLoss: 0.04043410792946815 	Avg.validLoss: 0.049375986271252524
# Epoch: 13, Batch: 140, Avg.TrainingLoss: 0.048537812381982806 	Avg.validLoss: 0.06385899471883484
# Epoch: 13, Batch: 150, Avg.TrainingLoss: 0.043373383954167365 	Avg.validLoss: 0.09694491911442638
# Epoch: 13, Batch: 160, Avg.TrainingLoss: 0.04853171706199646 	Avg.validLoss: 0.04751344601693698
# Epoch: 13, Batch: 170, Avg.TrainingLoss: 0.050365690141916275 	Avg.validLoss: 0.033791640132794835
# Epoch: 13, Batch: 180, Avg.TrainingLoss: 0.0447568716481328 	Avg.validLoss: 0.07203266729810678
# Epoch: 13, Batch: 190, Avg.TrainingLoss: 0.04961582887917757 	Avg.validLoss: 0.035303461263117765
# Epoch: 13, Batch: 200, Avg.TrainingLoss: 0.04027488362044096 	Avg.validLoss: 0.05937817145806517
# Epoch: 13, Batch: 210, Avg.TrainingLoss: 0.03616595417261124 	Avg.validLoss: 0.04127141228214854
# Epoch: 13, Batch: 220, Avg.TrainingLoss: 0.047509940527379516 	Avg.validLoss: 0.07854543017987915
# Epoch: 13, Batch: 230, Avg.TrainingLoss: 0.03541461899876595 	Avg.validLoss: 0.033863025658220226
# Epoch: 13, Batch: 240, Avg.TrainingLoss: 0.03787411618977785 	Avg.validLoss: 0.07598654380488085
# Epoch: 13, Batch: 250, Avg.TrainingLoss: 0.039933128468692305 	Avg.validLoss: 0.07982285416044424
# Epoch: 13, Batch: 260, Avg.TrainingLoss: 0.029725362360477448 	Avg.validLoss: 0.05027907157607506
# Epoch: 13, Batch: 270, Avg.TrainingLoss: 0.0393769383430481 	Avg.validLoss: 0.05472233806968252
# Epoch: 13, Batch: 280, Avg.TrainingLoss: 0.03845947682857513 	Avg.validLoss: 0.08399538623136764
# Epoch: 13, Batch: 290, Avg.TrainingLoss: 0.029599179700016975 	Avg.validLoss: 0.04134921790396719
# Epoch: 13, Batch: 300, Avg.TrainingLoss: 0.18760801590979098 	Avg.validLoss: 0.032394868187132594
# Validation loss decreased (0.032998 --> 0.032395).  Saving model ...
# Epoch: 13, Batch: 310, Avg.TrainingLoss: 0.09861190915107727 	Avg.validLoss: 0.10666314367140303
# Epoch: 14, Batch: 10, Avg.TrainingLoss: 0.06847869344055653 	Avg.validLoss: 0.03768198515121648
# Epoch: 14, Batch: 20, Avg.TrainingLoss: 0.04920333549380303 	Avg.validLoss: 0.038333592365759644
# Epoch: 14, Batch: 30, Avg.TrainingLoss: 0.07592409998178482 	Avg.validLoss: 0.07121727247372528
# Epoch: 14, Batch: 40, Avg.TrainingLoss: 0.04537643771618605 	Avg.validLoss: 0.06125655660481122
# Epoch: 14, Batch: 50, Avg.TrainingLoss: 0.03506177924573421 	Avg.validLoss: 0.06996099228803822
# Epoch: 14, Batch: 60, Avg.TrainingLoss: 0.050842778943479064 	Avg.validLoss: 0.06409408486948881
# Epoch: 14, Batch: 70, Avg.TrainingLoss: 0.040145942755043504 	Avg.validLoss: 0.048949712338302864
# Epoch: 14, Batch: 80, Avg.TrainingLoss: 0.03732049353420734 	Avg.validLoss: 0.07003758662525629
# Epoch: 14, Batch: 90, Avg.TrainingLoss: 0.03390497677028179 	Avg.validLoss: 0.04934748376294367
# Epoch: 14, Batch: 100, Avg.TrainingLoss: 0.04713310468941927 	Avg.validLoss: 0.04264478953932062
# Epoch: 14, Batch: 110, Avg.TrainingLoss: 0.03972051329910755 	Avg.validLoss: 0.03148531659662379
# Validation loss decreased (0.032395 --> 0.031485).  Saving model ...
# Epoch: 14, Batch: 120, Avg.TrainingLoss: 0.02976107206195593 	Avg.validLoss: 0.060904332398937625
# Epoch: 14, Batch: 130, Avg.TrainingLoss: 0.0692877497524023 	Avg.validLoss: 0.04124170626820512
# Epoch: 14, Batch: 140, Avg.TrainingLoss: 0.039675554260611534 	Avg.validLoss: 0.08985758137302419
# Epoch: 14, Batch: 150, Avg.TrainingLoss: 0.04352532755583525 	Avg.validLoss: 0.03643384197931414
# Epoch: 14, Batch: 160, Avg.TrainingLoss: 0.03511945102363825 	Avg.validLoss: 0.056906324633628644
# Epoch: 14, Batch: 170, Avg.TrainingLoss: 0.03628881927579641 	Avg.validLoss: 0.051446325883183174
# Epoch: 14, Batch: 180, Avg.TrainingLoss: 0.05563039593398571 	Avg.validLoss: 0.08268276434068736
# Epoch: 14, Batch: 190, Avg.TrainingLoss: 0.039865273609757425 	Avg.validLoss: 0.04756003661307296
# Epoch: 14, Batch: 200, Avg.TrainingLoss: 0.04728786889463663 	Avg.validLoss: 0.09237713708052402
# Epoch: 14, Batch: 210, Avg.TrainingLoss: 0.04529265891760588 	Avg.validLoss: 0.11609374750082549
# Epoch: 14, Batch: 220, Avg.TrainingLoss: 0.0393654203042388 	Avg.validLoss: 0.09923364934807569
# Epoch: 14, Batch: 230, Avg.TrainingLoss: 0.038774734176695344 	Avg.validLoss: 0.0541388478420804
# Epoch: 14, Batch: 240, Avg.TrainingLoss: 0.07917005158960819 	Avg.validLoss: 0.059313103395131975
# Epoch: 14, Batch: 250, Avg.TrainingLoss: 0.03875577263534069 	Avg.validLoss: 0.030144363550221646
# Validation loss decreased (0.031485 --> 0.030144).  Saving model ...
# Epoch: 14, Batch: 260, Avg.TrainingLoss: 0.20593011956661939 	Avg.validLoss: 0.037060849411639174
# Epoch: 14, Batch: 270, Avg.TrainingLoss: 0.04639377351850271 	Avg.validLoss: 0.03373353238718186
# Epoch: 14, Batch: 280, Avg.TrainingLoss: 0.03736406285315752 	Avg.validLoss: 0.0851702088264027
# Epoch: 14, Batch: 290, Avg.TrainingLoss: 0.0629808608442545 	Avg.validLoss: 0.06702460397056417
# Epoch: 14, Batch: 300, Avg.TrainingLoss: 0.03410140313208103 	Avg.validLoss: 0.04839524333338344
# Epoch: 14, Batch: 310, Avg.TrainingLoss: 0.042258713953197004 	Avg.validLoss: 0.030600514445949155
# Epoch: 15, Batch: 10, Avg.TrainingLoss: 0.03151735197752714 	Avg.validLoss: 0.03297636438850206
# Epoch: 15, Batch: 20, Avg.TrainingLoss: 0.05049417894333601 	Avg.validLoss: 0.07334564301061493
# Epoch: 15, Batch: 30, Avg.TrainingLoss: 0.04596186820417643 	Avg.validLoss: 0.07439759406503398
# Epoch: 15, Batch: 40, Avg.TrainingLoss: 0.049621401354670525 	Avg.validLoss: 0.07185558931137613
# Epoch: 15, Batch: 50, Avg.TrainingLoss: 0.044458099827170375 	Avg.validLoss: 0.03759828466125306
# Epoch: 15, Batch: 60, Avg.TrainingLoss: 0.04770711362361908 	Avg.validLoss: 0.0498110184047608
# Epoch: 15, Batch: 70, Avg.TrainingLoss: 0.03842981569468975 	Avg.validLoss: 0.0685987905249258
# Epoch: 15, Batch: 80, Avg.TrainingLoss: 0.04189425762742758 	Avg.validLoss: 0.05057532092653258
# Epoch: 15, Batch: 90, Avg.TrainingLoss: 0.0969991149380803 	Avg.validLoss: 0.03779691455595066
# Epoch: 15, Batch: 100, Avg.TrainingLoss: 0.051926019787788394 	Avg.validLoss: 0.09204137165939187
# Epoch: 15, Batch: 110, Avg.TrainingLoss: 0.04764488097280264 	Avg.validLoss: 0.07412069162213905
# Epoch: 15, Batch: 120, Avg.TrainingLoss: 0.06388916242867708 	Avg.validLoss: 0.054761544892812056
# Epoch: 15, Batch: 130, Avg.TrainingLoss: 0.046980703808367254 	Avg.validLoss: 0.04441151866484756
# Epoch: 15, Batch: 140, Avg.TrainingLoss: 0.046830718964338304 	Avg.validLoss: 0.0732582632312282
# Epoch: 15, Batch: 150, Avg.TrainingLoss: 0.19501466285437347 	Avg.validLoss: 0.03695798531777597
# Epoch: 15, Batch: 160, Avg.TrainingLoss: 0.045237944833934306 	Avg.validLoss: 0.0335219230050641
# Epoch: 15, Batch: 170, Avg.TrainingLoss: 0.04650076180696487 	Avg.validLoss: 0.045583459839354024
# Epoch: 15, Batch: 180, Avg.TrainingLoss: 0.042137584649026394 	Avg.validLoss: 0.09308972029887527
# Epoch: 15, Batch: 190, Avg.TrainingLoss: 0.05452081691473722 	Avg.validLoss: 0.043553128176384924
# Epoch: 15, Batch: 200, Avg.TrainingLoss: 0.05289445426315069 	Avg.validLoss: 0.040174577535921435
# Epoch: 15, Batch: 210, Avg.TrainingLoss: 0.036128163896501066 	Avg.validLoss: 0.034022885051722816
# Epoch: 15, Batch: 220, Avg.TrainingLoss: 0.04055216535925865 	Avg.validLoss: 0.031536221907963985
# Epoch: 15, Batch: 230, Avg.TrainingLoss: 0.03927123975008726 	Avg.validLoss: 0.06665187909380894
# Epoch: 15, Batch: 240, Avg.TrainingLoss: 0.06395291741937399 	Avg.validLoss: 0.04552683190071169
# Epoch: 15, Batch: 250, Avg.TrainingLoss: 0.05171691887080669 	Avg.validLoss: 0.03798710494544465
# Epoch: 15, Batch: 260, Avg.TrainingLoss: 0.03910308349877596 	Avg.validLoss: 0.05669402938357667
# Epoch: 15, Batch: 270, Avg.TrainingLoss: 0.04674285147339106 	Avg.validLoss: 0.09025136622562574
# Epoch: 15, Batch: 280, Avg.TrainingLoss: 0.036973907612264156 	Avg.validLoss: 0.05212830390372028
# Epoch: 15, Batch: 290, Avg.TrainingLoss: 0.04178894869983196 	Avg.validLoss: 0.0631695434537237
# Epoch: 15, Batch: 300, Avg.TrainingLoss: 0.04062105696648359 	Avg.validLoss: 0.031632752416149386
# Epoch: 15, Batch: 310, Avg.TrainingLoss: 0.037197227217257024 	Avg.validLoss: 0.028938775629106628
# Validation loss decreased (0.030144 --> 0.028939).  Saving model ...
# Epoch: 16, Batch: 10, Avg.TrainingLoss: 0.06530700977891683 	Avg.validLoss: 0.028485488200377176
# Validation loss decreased (0.028939 --> 0.028485).  Saving model ...
# Epoch: 16, Batch: 20, Avg.TrainingLoss: 0.03710957616567612 	Avg.validLoss: 0.08523614662618652
# Epoch: 16, Batch: 30, Avg.TrainingLoss: 0.04282060768455267 	Avg.validLoss: 0.04878957750480299
# Epoch: 16, Batch: 40, Avg.TrainingLoss: 0.04468114115297794 	Avg.validLoss: 0.05294668272869779
# Epoch: 16, Batch: 50, Avg.TrainingLoss: 0.04939412176609039 	Avg.validLoss: 0.12568000537165672
# Epoch: 16, Batch: 60, Avg.TrainingLoss: 0.03331978153437376 	Avg.validLoss: 0.0673471888893343
# Epoch: 16, Batch: 70, Avg.TrainingLoss: 0.032215173915028573 	Avg.validLoss: 0.030013454749620375
# Epoch: 16, Batch: 80, Avg.TrainingLoss: 0.04219584129750729 	Avg.validLoss: 0.04883266721631405
# Epoch: 16, Batch: 90, Avg.TrainingLoss: 0.034023841843008995 	Avg.validLoss: 0.06793023027867251
# Epoch: 16, Batch: 100, Avg.TrainingLoss: 0.04101896695792675 	Avg.validLoss: 0.08441759811746592
# Epoch: 16, Batch: 110, Avg.TrainingLoss: 0.03697969112545252 	Avg.validLoss: 0.0983538789502372
# ...
# Epoch: 30, Batch: 230, Avg.TrainingLoss: 0.04744351264089346 	Avg.validLoss: 0.024664853726422166
# Epoch: 30, Batch: 240, Avg.TrainingLoss: 0.04227484604343772 	Avg.validLoss: 0.06352431582276187
# Epoch: 30, Batch: 250, Avg.TrainingLoss: 0.02769664041697979 	Avg.validLoss: 0.08917649012769578
# Epoch: 30, Batch: 260, Avg.TrainingLoss: 0.03166276440024376 	Avg.validLoss: 0.1335699019975142
# Epoch: 30, Batch: 270, Avg.TrainingLoss: 0.024944274127483367 	Avg.validLoss: 0.020923409314901498
# Epoch: 30, Batch: 280, Avg.TrainingLoss: 0.03947246838361025 	Avg.validLoss: 0.04580630786243202
# Epoch: 30, Batch: 290, Avg.TrainingLoss: 0.03708156533539295 	Avg.validLoss: 0.033460346971116314
# Epoch: 30, Batch: 300, Avg.TrainingLoss: 0.09221953712403774 	Avg.validLoss: 0.037267079975219136
# Epoch: 30, Batch: 310, Avg.TrainingLoss: 0.02618131060153246 	Avg.validLoss: 0.060277572332348435
# Epoch: 31, Batch: 10, Avg.TrainingLoss: 0.03002321682870388 	Avg.validLoss: 0.05339303479201532
# Epoch: 31, Batch: 20, Avg.TrainingLoss: 0.03135679606348276 	Avg.validLoss: 0.030774390136532357
# Epoch: 31, Batch: 30, Avg.TrainingLoss: 0.03573052641004324 	Avg.validLoss: 0.03974820874803672
# Epoch: 31, Batch: 40, Avg.TrainingLoss: 0.027596785314381124 	Avg.validLoss: 0.04024561446138545
# Epoch: 31, Batch: 50, Avg.TrainingLoss: 0.0315492644906044 	Avg.validLoss: 0.04850599104592394
# Epoch: 31, Batch: 60, Avg.TrainingLoss: 0.03994983639568091 	Avg.validLoss: 0.05499965583937878
# Epoch: 31, Batch: 70, Avg.TrainingLoss: 0.04018367864191532 	Avg.validLoss: 0.08266744419200228
# Epoch: 31, Batch: 80, Avg.TrainingLoss: 0.027146396972239018 	Avg.validLoss: 0.042265540801763875
# Epoch: 31, Batch: 90, Avg.TrainingLoss: 0.029773490875959395 	Avg.validLoss: 0.028997365589861924
# Epoch: 31, Batch: 100, Avg.TrainingLoss: 0.0542364438995719 	Avg.validLoss: 0.11652980473516994
# Epoch: 31, Batch: 110, Avg.TrainingLoss: 0.022937114536762237 	Avg.validLoss: 0.03707524380953498
# Epoch: 31, Batch: 120, Avg.TrainingLoss: 0.034207535721361634 	Avg.validLoss: 0.050056022807223606
# Epoch: 31, Batch: 130, Avg.TrainingLoss: 0.08510757833719254 	Avg.validLoss: 0.023808443428937755
# Epoch: 31, Batch: 140, Avg.TrainingLoss: 0.03441536165773869 	Avg.validLoss: 0.028620297062302257
# Epoch: 31, Batch: 150, Avg.TrainingLoss: 0.06099871452897787 	Avg.validLoss: 0.09432821841425978
# Epoch: 31, Batch: 160, Avg.TrainingLoss: 0.04650103729218245 	Avg.validLoss: 0.028022485462184242
# Epoch: 31, Batch: 170, Avg.TrainingLoss: 0.03530973698943853 	Avg.validLoss: 0.021294982931603583
# Epoch: 31, Batch: 180, Avg.TrainingLoss: 0.027736970223486423 	Avg.validLoss: 0.06067684552809923
# Epoch: 31, Batch: 190, Avg.TrainingLoss: 0.031050672568380833 	Avg.validLoss: 0.022393406094240315
# Epoch: 31, Batch: 200, Avg.TrainingLoss: 0.04418845623731613 	Avg.validLoss: 0.1144952282600234
# Epoch: 31, Batch: 210, Avg.TrainingLoss: 0.037443560920655726 	Avg.validLoss: 0.04356064168854773
# Epoch: 31, Batch: 220, Avg.TrainingLoss: 0.03367183730006218 	Avg.validLoss: 0.09888354847692168
# Epoch: 31, Batch: 230, Avg.TrainingLoss: 0.028935318253934382 	Avg.validLoss: 0.05327334818618663
# Epoch: 31, Batch: 240, Avg.TrainingLoss: 0.02833608165383339 	Avg.validLoss: 0.12541253413100636
# Epoch: 31, Batch: 250, Avg.TrainingLoss: 0.03268568441271782 	Avg.validLoss: 0.09722518993035562
# Epoch: 31, Batch: 260, Avg.TrainingLoss: 0.036929693445563315 	Avg.validLoss: 0.026153110915181264
# Epoch: 31, Batch: 270, Avg.TrainingLoss: 0.04611045159399509 	Avg.validLoss: 0.04511217231393894
# Epoch: 31, Batch: 280, Avg.TrainingLoss: 0.0342120623216033 	Avg.validLoss: 0.03704219825049011
# Epoch: 31, Batch: 290, Avg.TrainingLoss: 0.030271058902144432 	Avg.validLoss: 0.024080752029024453
# Epoch: 31, Batch: 300, Avg.TrainingLoss: 0.03575137779116631 	Avg.validLoss: 0.06047801889823696
# Epoch: 31, Batch: 310, Avg.TrainingLoss: 0.028929611295461656 	Avg.validLoss: 0.03717374293445852
# Epoch: 32, Batch: 10, Avg.TrainingLoss: 0.030006345361471176 	Avg.validLoss: 0.020289129679861094
# Epoch: 32, Batch: 20, Avg.TrainingLoss: 0.021008091513067484 	Avg.validLoss: 0.027011971721544084
# Epoch: 32, Batch: 30, Avg.TrainingLoss: 0.027596521377563476 	Avg.validLoss: 0.05581733162347981
# Epoch: 32, Batch: 40, Avg.TrainingLoss: 0.0209266509860754 	Avg.validLoss: 0.024529676076907644
# Epoch: 32, Batch: 50, Avg.TrainingLoss: 0.055349189601838586 	Avg.validLoss: 0.05260893571691189
# Epoch: 32, Batch: 60, Avg.TrainingLoss: 0.03606820870190859 	Avg.validLoss: 0.0528194544826112
# Epoch: 32, Batch: 70, Avg.TrainingLoss: 0.038838330283761026 	Avg.validLoss: 0.06942616579138991
# Epoch: 32, Batch: 80, Avg.TrainingLoss: 0.03687012791633606 	Avg.validLoss: 0.041943912615062875
# Epoch: 32, Batch: 90, Avg.TrainingLoss: 0.034037454146891834 	Avg.validLoss: 0.03629516422576298
# Epoch: 32, Batch: 100, Avg.TrainingLoss: 0.042500208504498004 	Avg.validLoss: 0.07230188204998397
# Epoch: 32, Batch: 110, Avg.TrainingLoss: 0.035122739523649214 	Avg.validLoss: 0.05237095324441016
# Epoch: 32, Batch: 120, Avg.TrainingLoss: 0.03960615321993828 	Avg.validLoss: 0.028282809636496396
# Epoch: 32, Batch: 130, Avg.TrainingLoss: 0.0337743959389627 	Avg.validLoss: 0.0861248552713091
# Epoch: 32, Batch: 140, Avg.TrainingLoss: 0.08038606978952885 	Avg.validLoss: 0.05205877916618234
# Epoch: 32, Batch: 150, Avg.TrainingLoss: 0.035006148554384706 	Avg.validLoss: 0.02707077655941248
# Epoch: 32, Batch: 160, Avg.TrainingLoss: 0.027276394329965113 	Avg.validLoss: 0.046051634863191256
# Epoch: 32, Batch: 170, Avg.TrainingLoss: 0.03522595530375838 	Avg.validLoss: 0.04555063079934933
# Epoch: 32, Batch: 180, Avg.TrainingLoss: 0.03206799104809761 	Avg.validLoss: 0.055007928675525106
# Epoch: 32, Batch: 190, Avg.TrainingLoss: 0.03747297488152981 	Avg.validLoss: 0.1380525608520115
# Epoch: 32, Batch: 200, Avg.TrainingLoss: 0.033426861837506296 	Avg.validLoss: 0.05762690201810847
# Epoch: 32, Batch: 210, Avg.TrainingLoss: 0.02992565631866455 	Avg.validLoss: 0.049406603527809845
# Epoch: 32, Batch: 220, Avg.TrainingLoss: 0.02764098849147558 	Avg.validLoss: 0.040882432704113125
# Epoch: 32, Batch: 230, Avg.TrainingLoss: 0.04267843989655375 	Avg.validLoss: 0.07683148451493998
# Epoch: 32, Batch: 240, Avg.TrainingLoss: 0.021336877066642047 	Avg.validLoss: 0.03756375065493274
# Epoch: 32, Batch: 250, Avg.TrainingLoss: 0.04893004354089499 	Avg.validLoss: 0.042752711253100734
# Epoch: 32, Batch: 260, Avg.TrainingLoss: 0.03385714646428824 	Avg.validLoss: 0.023094324389677172
# Epoch: 32, Batch: 270, Avg.TrainingLoss: 0.030370476469397546 	Avg.validLoss: 0.05027904845451171
# Epoch: 32, Batch: 280, Avg.TrainingLoss: 0.026914138905704023 	Avg.validLoss: 0.021704235706327624
# Epoch: 32, Batch: 290, Avg.TrainingLoss: 0.03106792699545622 	Avg.validLoss: 0.054760867692099494
# Epoch: 32, Batch: 300, Avg.TrainingLoss: 0.026627963036298753 	Avg.validLoss: 0.021279653900362162
# Epoch: 32, Batch: 310, Avg.TrainingLoss: 0.024195002019405366 	Avg.validLoss: 0.048231997317230775
# Epoch: 33, Batch: 10, Avg.TrainingLoss: 0.024754920229315757 	Avg.validLoss: 0.039631959045510416
# Epoch: 33, Batch: 20, Avg.TrainingLoss: 0.05911028813570738 	Avg.validLoss: 0.09888612840195439
# Epoch: 33, Batch: 30, Avg.TrainingLoss: 0.1480655876919627 	Avg.validLoss: 0.04950916405358066
# Epoch: 33, Batch: 40, Avg.TrainingLoss: 0.03855583090335131 	Avg.validLoss: 0.06711692366253778
# Epoch: 33, Batch: 50, Avg.TrainingLoss: 0.040874247439205647 	Avg.validLoss: 0.06604852563986889
# Epoch: 33, Batch: 60, Avg.TrainingLoss: 0.04279363378882408 	Avg.validLoss: 0.05885359742328783
# Epoch: 33, Batch: 70, Avg.TrainingLoss: 0.03209889885038138 	Avg.validLoss: 0.0715600620050823
# Epoch: 33, Batch: 80, Avg.TrainingLoss: 0.03571621123701334 	Avg.validLoss: 0.043801739435061555
# Epoch: 33, Batch: 90, Avg.TrainingLoss: 0.03284744583070278 	Avg.validLoss: 0.040179328896062225
# Epoch: 33, Batch: 100, Avg.TrainingLoss: 0.06139705013483763 	Avg.validLoss: 0.05562261231458945
# Epoch: 33, Batch: 110, Avg.TrainingLoss: 0.041748779639601705 	Avg.validLoss: 0.07885649092387774
# Epoch: 33, Batch: 120, Avg.TrainingLoss: 0.03872507903724909 	Avg.validLoss: 0.0249005133835222
# Epoch: 33, Batch: 130, Avg.TrainingLoss: 0.03233877383172512 	Avg.validLoss: 0.062089628685330384
# Epoch: 33, Batch: 140, Avg.TrainingLoss: 0.03257159646600485 	Avg.validLoss: 0.09711013471632335
# Epoch: 33, Batch: 150, Avg.TrainingLoss: 0.029022829979658125 	Avg.validLoss: 0.0914783505292211
# Epoch: 33, Batch: 160, Avg.TrainingLoss: 0.03572378791868687 	Avg.validLoss: 0.030156264291548662
# Epoch: 33, Batch: 170, Avg.TrainingLoss: 0.028620576485991478 	Avg.validLoss: 0.051148023424034864
# Epoch: 33, Batch: 180, Avg.TrainingLoss: 0.040173407085239886 	Avg.validLoss: 0.103406430265161
# Epoch: 33, Batch: 190, Avg.TrainingLoss: 0.03149420097470283 	Avg.validLoss: 0.04200097727939228
# Epoch: 33, Batch: 200, Avg.TrainingLoss: 0.03014188036322594 	Avg.validLoss: 0.04132341036325418
# Epoch: 33, Batch: 210, Avg.TrainingLoss: 0.03137838542461395 	Avg.validLoss: 0.04649312878727396
# Epoch: 33, Batch: 220, Avg.TrainingLoss: 0.02745249941945076 	Avg.validLoss: 0.034015547494926204
# Epoch: 33, Batch: 230, Avg.TrainingLoss: 0.033668357878923416 	Avg.validLoss: 0.055849122561815845
# Epoch: 33, Batch: 240, Avg.TrainingLoss: 0.02921480033546686 	Avg.validLoss: 0.042674370093884834
# Epoch: 33, Batch: 250, Avg.TrainingLoss: 0.03091939939185977 	Avg.validLoss: 0.05794506840343248
# Epoch: 33, Batch: 260, Avg.TrainingLoss: 0.03466935083270073 	Avg.validLoss: 0.049374998369485654
# Epoch: 33, Batch: 270, Avg.TrainingLoss: 0.04777676425874233 	Avg.validLoss: 0.021965086158644946
# Epoch: 33, Batch: 280, Avg.TrainingLoss: 0.029375747404992582 	Avg.validLoss: 0.02473865218482093
# Epoch: 33, Batch: 290, Avg.TrainingLoss: 0.03172609638422728 	Avg.validLoss: 0.04819967738228899
# Epoch: 33, Batch: 300, Avg.TrainingLoss: 0.027512103132903577 	Avg.validLoss: 0.06383258617897598
# Epoch: 33, Batch: 310, Avg.TrainingLoss: 0.03528152741491795 	Avg.validLoss: 0.04436708289613096
# Epoch: 34, Batch: 10, Avg.TrainingLoss: 0.029419710487127305 	Avg.validLoss: 0.12030037916723013
# Epoch: 34, Batch: 20, Avg.TrainingLoss: 0.03558987975120544 	Avg.validLoss: 0.0909376229466386
# Epoch: 34, Batch: 30, Avg.TrainingLoss: 0.027298551797866822 	Avg.validLoss: 0.043108498790662066
# Epoch: 34, Batch: 40, Avg.TrainingLoss: 0.0249508373439312 	Avg.validLoss: 0.024274026468999125
# Epoch: 34, Batch: 50, Avg.TrainingLoss: 0.027066540345549582 	Avg.validLoss: 0.026646846867667114
# Epoch: 34, Batch: 60, Avg.TrainingLoss: 0.02641330659389496 	Avg.validLoss: 0.02042515367549451
# Epoch: 34, Batch: 70, Avg.TrainingLoss: 0.045014550909399986 	Avg.validLoss: 0.04618696540034231
# Epoch: 34, Batch: 80, Avg.TrainingLoss: 0.059229850117117164 	Avg.validLoss: 0.05757730098904213
# Epoch: 34, Batch: 90, Avg.TrainingLoss: 0.025876407232135534 	Avg.validLoss: 0.09630113522484468
# Epoch: 34, Batch: 100, Avg.TrainingLoss: 0.03159853927791119 	Avg.validLoss: 0.053789271956923373
# Epoch: 34, Batch: 110, Avg.TrainingLoss: 0.041435718350112435 	Avg.validLoss: 0.038737901486456394
# Epoch: 34, Batch: 120, Avg.TrainingLoss: 0.027657769992947577 	Avg.validLoss: 0.05398585703331611
# Epoch: 34, Batch: 130, Avg.TrainingLoss: 0.030096930265426636 	Avg.validLoss: 0.05424402201968121
# Epoch: 34, Batch: 140, Avg.TrainingLoss: 0.0395936100743711 	Avg.validLoss: 0.02383956252301187
# Epoch: 34, Batch: 150, Avg.TrainingLoss: 0.030119330435991288 	Avg.validLoss: 0.03296157891587542
# Epoch: 34, Batch: 160, Avg.TrainingLoss: 0.03541520275175571 	Avg.validLoss: 0.07467572125094818
# Epoch: 34, Batch: 170, Avg.TrainingLoss: 0.025754637084901333 	Avg.validLoss: 0.06842431326994318
# Epoch: 34, Batch: 180, Avg.TrainingLoss: 0.030879061110317706 	Avg.validLoss: 0.08305709806373182
# Epoch: 34, Batch: 190, Avg.TrainingLoss: 0.03956184983253479 	Avg.validLoss: 0.06272833129509509
# Epoch: 34, Batch: 200, Avg.TrainingLoss: 0.03136644214391708 	Avg.validLoss: 0.036821350821353106
# Epoch: 34, Batch: 210, Avg.TrainingLoss: 0.027509827353060245 	Avg.validLoss: 0.03744859587551886
# Epoch: 34, Batch: 220, Avg.TrainingLoss: 0.0597174858674407 	Avg.validLoss: 0.08073665045546313
# Epoch: 34, Batch: 230, Avg.TrainingLoss: 0.03049047142267227 	Avg.validLoss: 0.09531202971009332
# Epoch: 34, Batch: 240, Avg.TrainingLoss: 0.03633567597717047 	Avg.validLoss: 0.025055622466640667
# Epoch: 34, Batch: 250, Avg.TrainingLoss: 0.024575204029679297 	Avg.validLoss: 0.054686443982484366
# Epoch: 34, Batch: 260, Avg.TrainingLoss: 0.038651454634964465 	Avg.validLoss: 0.058408033592637215
# Epoch: 34, Batch: 270, Avg.TrainingLoss: 0.032219069078564644 	Avg.validLoss: 0.02824377906481827
# Epoch: 34, Batch: 280, Avg.TrainingLoss: 0.026348798908293246 	Avg.validLoss: 0.05580257570554067
# Epoch: 34, Batch: 290, Avg.TrainingLoss: 0.04168549086898565 	Avg.validLoss: 0.040465093600009217
# Epoch: 34, Batch: 300, Avg.TrainingLoss: 0.026916840858757497 	Avg.validLoss: 0.10212467237768662
# Epoch: 34, Batch: 310, Avg.TrainingLoss: 0.032555841095745566 	Avg.validLoss: 0.09057741176143203
# Epoch: 35, Batch: 10, Avg.TrainingLoss: 0.032574355322867635 	Avg.validLoss: 0.03919174469404482
# Epoch: 35, Batch: 20, Avg.TrainingLoss: 0.03531261347234249 	Avg.validLoss: 0.02720380643371902
# Epoch: 35, Batch: 30, Avg.TrainingLoss: 0.05775521192699671 	Avg.validLoss: 0.05090916346263334
# Epoch: 35, Batch: 40, Avg.TrainingLoss: 0.036455223150551316 	Avg.validLoss: 0.03678408055700835
# Epoch: 35, Batch: 50, Avg.TrainingLoss: 0.04454529732465744 	Avg.validLoss: 0.025187908897897758
# Epoch: 35, Batch: 60, Avg.TrainingLoss: 0.03773689493536949 	Avg.validLoss: 0.036686356933087624
# Epoch: 35, Batch: 70, Avg.TrainingLoss: 0.025025500170886516 	Avg.validLoss: 0.09910890288823257
# Epoch: 35, Batch: 80, Avg.TrainingLoss: 0.03940429370850325 	Avg.validLoss: 0.11622665503810596
# Epoch: 35, Batch: 90, Avg.TrainingLoss: 0.026172561943531035 	Avg.validLoss: 0.08927114178679582
# Epoch: 35, Batch: 100, Avg.TrainingLoss: 0.024951280374079943 	Avg.validLoss: 0.1050104877529289
# Epoch: 35, Batch: 110, Avg.TrainingLoss: 0.026133476942777633 	Avg.validLoss: 0.03826419712512651
# Epoch: 35, Batch: 120, Avg.TrainingLoss: 0.02906990721821785 	Avg.validLoss: 0.0718067132873256
# Epoch: 35, Batch: 130, Avg.TrainingLoss: 0.032901099696755406 	Avg.validLoss: 0.0882305076475002
# Epoch: 35, Batch: 140, Avg.TrainingLoss: 0.03002755492925644 	Avg.validLoss: 0.04559385883648789
# Epoch: 35, Batch: 150, Avg.TrainingLoss: 0.0462409695610404 	Avg.validLoss: 0.0450392936038747
# Epoch: 35, Batch: 160, Avg.TrainingLoss: 0.04659678116440773 	Avg.validLoss: 0.025405782554836977
# Epoch: 35, Batch: 170, Avg.TrainingLoss: 0.04147246442735195 	Avg.validLoss: 0.03656953468251263
# Epoch: 35, Batch: 180, Avg.TrainingLoss: 0.026242029387503862 	Avg.validLoss: 0.04286201482348015
# Epoch: 35, Batch: 190, Avg.TrainingLoss: 0.031047489494085312 	Avg.validLoss: 0.05970229567001665
# Epoch: 35, Batch: 200, Avg.TrainingLoss: 0.026416460052132607 	Avg.validLoss: 0.09500211869188815
# Epoch: 35, Batch: 210, Avg.TrainingLoss: 0.029122720286250115 	Avg.validLoss: 0.04895776047269044
# Epoch: 35, Batch: 220, Avg.TrainingLoss: 0.02554077673703432 	Avg.validLoss: 0.06986175938320986
# Epoch: 35, Batch: 230, Avg.TrainingLoss: 0.022131979558616878 	Avg.validLoss: 0.08439629712825739
# Epoch: 35, Batch: 240, Avg.TrainingLoss: 0.023524594120681287 	Avg.validLoss: 0.04252896054696313
# Epoch: 35, Batch: 250, Avg.TrainingLoss: 0.03325668144971132 	Avg.validLoss: 0.02720616722877832
# Epoch: 35, Batch: 260, Avg.TrainingLoss: 0.020682645216584205 	Avg.validLoss: 0.023672737294237394
# Epoch: 35, Batch: 270, Avg.TrainingLoss: 0.04223903268575668 	Avg.validLoss: 0.03825794065618791
# Epoch: 35, Batch: 280, Avg.TrainingLoss: 0.02874708604067564 	Avg.validLoss: 0.0557730462660507
# Epoch: 35, Batch: 290, Avg.TrainingLoss: 0.032305166497826575 	Avg.validLoss: 0.029326673150277892
# Epoch: 35, Batch: 300, Avg.TrainingLoss: 0.03221048545092344 	Avg.validLoss: 0.023066876752226684
# Epoch: 35, Batch: 310, Avg.TrainingLoss: 0.027703700959682463 	Avg.validLoss: 0.045683965318421754
# Finished Training

# %%
net.load_state_dict(torch.load('saved_models/keypoints_model_best_valid.pt'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([10, 1, 224, 224])
# torch.Size([10, 68, 2])
# torch.Size([10, 68, 2])

# %%
## DONE: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!
#
# Save your models but please **delete any checkpoints and saved models before you submit your project** otherwise your workspace may be too large to submit.

# %%
## DONE: change the name to something uniqe for each new model
model_dir = 'saved_models/'
model_name = 'keypoints_model_1.pt'

# after training, save your model parameters in the dir 'saved_models'
# torch.save(net.state_dict(), model_dir+model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**:
#
# I use MSELoss function, because it's a regular loss function that regression problem can use.<br/>
# And I use Adam optimizer (optim.Adam), because I have compared it with optim.RMSprop, and optim.Adam just produce a better result.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# **Answer**:
#
# I start with a architecutre like below
#
# Net(<br/>
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))<br/>
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)<br/>
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))<br/>
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)<br/>
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))<br/>
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)<br/>
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))<br/>
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)<br/>
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)<br/>
#   (fc1): Linear(in_features=43264, out_features=6362, bias=True)<br/>
#   (fc2): Linear(in_features=6362, out_features=935, bias=True)<br/>
#   (fc3): Linear(in_features=935, out_features=136, bias=True)<br/>
#   (dropout): Dropout(p=0.4, inplace=False)<br/>
# )<br/>
#
# But it didn't perform well compared to my last architecture, after reference 《Facial Key Points Detection using Deep Convolutional Neural Network - NaimishNet》(https://arxiv.org/pdf/1710.00977.pdf) , I remove BatchNorm2d layers and add more dropout layer but with increasing dropout probability.<br/>
# And finally, it did well.

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# **Answer**:
#
# I try batch_size 30,20,10 for 2 epochs, and when batch_size=10 the final loss is relatively lower, so I choose batch_size=10.<br/>
# I try to run epochs=80, and I found there are no improvement for valid loss between epoch=34 and epoch=48,so I choose epochs=35

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.conv1.weight.data

w = weights1.cpu().numpy()

filter_index = 0

print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')
# Out:
# [[ 0.14947368  0.09047651  0.07186607 -0.02723125 -0.06599351]
#  [-0.03032096 -0.01475493 -0.13202605  0.04797966  0.11923097]
#  [ 0.00652877 -0.20035431  0.06558309 -0.14157388 -0.06859265]
#  [-0.01229047 -0.25480023 -0.03604641 -0.10440291  0.09641772]
#  [-0.18769082 -0.21660328 -0.27052733 -0.07328267  0.08476323]]
# (5, 5)

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
## DONE: load in and display any image from the transformed test dataset
dataiter = iter(test_loader)
sample = dataiter.next()
test_image = sample['image'][0].squeeze()
plt.imshow(test_image, cmap='gray')

## DONE: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image

import cv2
weights = net.conv1.weight.data
w = weights.cpu().numpy()

fig=plt.figure(figsize=(30, 5))
columns = 2*5
for i in range(0, columns):
    fig.add_subplot(1, columns, i+1)
    if ((i%2)==0):
        plt.imshow(w[int(i/2)][0], cmap='gray')
    else:
        c = cv2.filter2D(test_image.numpy(), -1, w[int((i-1)/2)][0])
        plt.imshow(c, cmap='gray')
plt.show()

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**:
#
# for the fourth filter, top is relatively high pixel value, bottom is relatively low pixel value, so it detect horizontal line, and resulst shows that is right.

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
